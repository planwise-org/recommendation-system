# %%
import pandas as pd

# Load the dataset
file_path = "/Users/alexandrakhreiche/Desktop/code/planwise_chatbots/recommendation-system/api/combined_google_review_ratings.csv"  # Update with your actual path
df = pd.read_csv(file_path, low_memory=False)

# Drop the 'Unnamed: 25' column if it exists
if 'Unnamed: 25' in df.columns:
    df.drop(columns=['Unnamed: 25'], inplace=True)

# Merge 'Zoo' and 'zoos' into one column 'zoo'
if 'Zoo' in df.columns and 'zoos' in df.columns:
    df['zoo'] = df[['Zoo', 'zoos']].max(axis=1)
    df.drop(columns=['Zoo', 'zoos'], inplace=True)

# Merge 'Supermarket' and 'Supermarkets' into 'supermarket'
if 'Supermarket' in df.columns and 'Supermarkets' in df.columns:
    df['supermarket'] = df[['Supermarket', 'Supermarkets']].max(axis=1)
    df.drop(columns=['Supermarket', 'Supermarkets'], inplace=True)

# Merge 'Stores' and 'Stores and Shopping' into 'stores'
if 'Stores' in df.columns and 'Stores and Shopping' in df.columns:
    df['stores'] = df[['Stores', 'Stores and Shopping']].max(axis=1)
    df.drop(columns=['Stores', 'Stores and Shopping'], inplace=True)

# Merge 'parks' and 'Park' into 'parks'
if 'parks' in df.columns and 'Park' in df.columns:
    df['parks'] = df[['parks', 'Park']].max(axis=1)
    df.drop(columns=['Park'], inplace=True)

# Drop the 'other' column if it exists
if 'Other' in df.columns:
    df.drop(columns=['Other'], inplace=True)

# %%
# Check if 'stores' column exists
if 'Stores' in df.columns:
    avg_stores = df['Stores'].mean()
    print(f"✅ The average value of the 'stores' column is: {avg_stores:.2f}")
else:
    print("⚠️ The 'stores' column was not found in the dataset.")
# Out:
# ✅ The average value of the 'stores' column is: 0.04

# %%
df.drop(columns=['Stores'], inplace=True)

# %%
# Check if 'stores' column exists
if 'Stores and shopping' in df.columns:
    avg_stores = df['Stores and shopping'].mean()
    print(f"✅ The average value of the 'Stores and shopping' column is: {avg_stores:.2f}")
else:
    print("⚠️ The 'Stores and shopping' column was not found in the dataset.")
# Out:
# ✅ The average value of the 'Stores and shopping' column is: 0.00

# %%
df.drop(columns=['Stores and shopping'], inplace=True)

# %%
# Check if 'stores' column exists
if 'gyms' in df.columns:
    gyms = df['gyms'].mean()
    print(f"✅ The average value of the 'gyms' column is: {gyms:.2f}")
else:
    print("⚠️ The 'gyms' column was not found in the dataset.")
# Out:
# ✅ The average value of the 'gyms' column is: 0.01

# %%
df.drop(columns=['gyms'], inplace=True)

# %%
# Check if 'stores' column exists
if 'Amusement Parks' in df.columns:
    AmusementParks = df['Amusement Parks'].mean()
    print(f"✅ The average value of the 'Amusement Parks' column is: {AmusementParks:.2f}")
else:
    print("⚠️ The 'Amusement Parks' column was not found in the dataset.")
# Out:
# ✅ The average value of the 'Amusement Parks' column is: 0.47

# %%
# Check if 'stores' column exists
if 'Entertainment' in df.columns:
    Entertainment = df['Entertainment'].mean()
    print(f"✅ The average value of the 'Entertainment' column is: {Entertainment:.2f}")
else:
    print("⚠️ The 'Entertainment' column was not found in the dataset.")
# Out:
# ✅ The average value of the 'Entertainment' column is: 0.00

# %%
df.drop(columns=['Entertainment'], inplace=True)

# %%
# Check if 'stores' column exists
if 'Farmer market' in df.columns:
    Farmermarket = df['Farmer market'].mean()
    print(f"✅ The average value of the 'Farmer market' column is: {Farmermarket:.2f}")
else:
    print("⚠️ The 'Farmer market' column was not found in the dataset.")
# Out:
# ✅ The average value of the 'Farmer market' column is: 0.29

# %%
# Check if 'stores' column exists
if 'Market' in df.columns:
    market = df['Market'].mean()
    print(f"✅ The average value of the 'Market' column is: {market:.2f}")
else:
    print("⚠️ The 'Market' column was not found in the dataset.")
# Out:
# ✅ The average value of the 'Market' column is: 0.82

# %%
# Check if 'stores' column exists
if 'Nature' in df.columns:
    Nature = df['Nature'].mean()
    print(f"✅ The average value of the 'Nature' column is: {Nature:.2f}")
else:
    print("⚠️ The 'Nature' column was not found in the dataset.")
# Out:
# ✅ The average value of the 'Nature' column is: 0.16

# %%
# Check if 'stores' column exists
if 'Tourist attractions' in df.columns:
    Touristattractions = df['Tourist attractions'].mean()
    print(f"✅ The average value of the 'Tourist attractions' column is: {Touristattractions:.2f}")
else:
    print("⚠️ The 'Tourist attractions' column was not found in the dataset.")
# Out:
# ✅ The average value of the 'Tourist attractions' column is: 0.88

# %%
# Check if 'stores' column exists
if 'churches' in df.columns:
    churches = df['churches'].mean()
    print(f"✅ The average value of the 'churches' column is: {churches:.2f}")
else:
    print("⚠️ The 'churches' column was not found in the dataset.")
# Out:
# ✅ The average value of the 'churches' column is: 0.03

# %%
df.drop(columns=['churches'], inplace=True)

# %%
# Check if 'stores' column exists
if 'cafes' in df.columns:
    cafes = df['cafes'].mean()
    print(f"✅ The average value of the 'cafes' column is: {cafes:.2f}")
else:
    print("⚠️ The 'cafes' column was not found in the dataset.")
# Out:
# ✅ The average value of the 'cafes' column is: 1.66

# %%
# Check if 'stores' column exists
if 'view points' in df.columns:
    viewpoints = df['cafes'].mean()
    print(f"✅ The average value of the 'view points' column is: {viewpoints:.2f}")
else:
    print("⚠️ The 'view points' column was not found in the dataset.")
# Out:
# ✅ The average value of the 'view points' column is: 1.66

# %%
# Check if 'stores' column exists
if 'monuments' in df.columns:
    monuments = df['cafes'].mean()
    print(f"✅ The average value of the 'monuments' column is: {monuments:.2f}")
else:
    print("⚠️ The 'monuments' column was not found in the dataset.")
# Out:
# ✅ The average value of the 'monuments' column is: 1.66

# %%
# Check if 'stores' column exists
if 'supermarket' in df.columns:
    supermarket = df['supermarket'].mean()
    print(f"✅ The average value of the 'supermarket' column is: {supermarket:.2f}")
else:
    print("⚠️ The 'supermarket' column was not found in the dataset.")
# Out:
# ✅ The average value of the 'supermarket' column is: 0.16

# %%
# Replace all 0.0 values with the mean of their respective columns
for column in df.columns:
    if df[column].dtype in ['float64', 'int64']:  # Ensure the column is numerical
        column_mean = df[df[column] != 0][column].mean()  # Compute mean excluding zeros
        df[column] = df[column].replace(0.0, column_mean)  # Replace 0s with mean

# %%
# Save the cleaned dataset as new_dataset.csv
cleaned_file_path = "new_dataset.csv"
df.to_csv(cleaned_file_path, index=False)

print(f"✅ Dataset cleaned and saved as {cleaned_file_path}")
# Out:
# ✅ Dataset cleaned and saved as new_dataset.csv

# %%
# Convert all columns to numeric (except 'User')
for column in df.columns:
    if column != 'User':  # Exclude 'User' column
        df[column] = pd.to_numeric(df[column], errors='coerce')  # Convert to numeric

# Replace all values below 1 with 1 (excluding 'User' column)
df.iloc[:, 1:] = df.iloc[:, 1:].applymap(lambda x: max(x, 1))

# %%
# Rename 'User' to 'user_id'
df = df.rename(columns={"User": "user_id"})

# %%
cleaned_file_path = "new_dataset.csv"
df.to_csv(cleaned_file_path, index=False)

print(f"✅ Dataset cleaned and saved as {cleaned_file_path}")
# Out:
# ✅ Dataset cleaned and saved as new_dataset.csv

# %%
# Get all column names (categories)
categories = df.columns.tolist()

# Print the categories
print("🔹 Categories in the dataset:")
print(categories)
# Out:
# 🔹 Categories in the dataset:
# ['user_id', 'resorts', 'burger/pizza shops', 'hotels/other lodgings', 'juice bars', 'beauty & spas', 'gardens', 'Amusement Parks', 'Farmer market', 'Market', 'Music halls', 'Nature', 'Tourist attractions', 'beaches', 'parks', 'theatres', 'museums', 'malls', 'restaurants', 'pubs/bars', 'local services', 'art galleries', 'dance clubs', 'swimming pools', 'bakeries', 'cafes', 'view points', 'monuments', 'zoo', 'supermarket']
